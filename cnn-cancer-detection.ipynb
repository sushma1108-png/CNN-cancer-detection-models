# %%
import pandas as pd
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import cv2
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0

# %%
train_labels = pd.read_csv('/kaggle/input/histopathologic-cancer-detection/train_labels.csv')
test_labels = pd.read_csv('/kaggle/input/histopathologic-cancer-detection/sample_submission.csv')
print(train_labels.head)
# Out:
# <bound method NDFrame.head of                                               id  label
# 0       f38a6374c348f90b587e046aac6079959adf3835      0
# 1       c18f2d887b7ae4f6742ee445113fa1aef383ed77      1
# 2       755db6279dae599ebb4d39a9123cce439965282d      0
# 3       bc3f0c64fb968ff4a8bd33af6971ecae77c75e08      0
# 4       068aba587a4950175d04c680d38943fd488d6a9d      0
# ...                                          ...    ...
# 220020  53e9aa9d46e720bf3c6a7528d1fca3ba6e2e49f6      0
# 220021  d4b854fe38b07fe2831ad73892b3cec877689576      1
# 220022  3d046cead1a2a5cbe00b2b4847cfb7ba7cf5fe75      0
# 220023  f129691c13433f66e1e0671ff1fe80944816f5a2      0
# 220024  a81f84895ddcd522302ddf34be02eb1b3e5af1cb      1
#
# [220025 rows x 2 columns]>

# %%
print(train_labels.shape)
# Out:
# (220025, 2)

# %% [markdown]
# # Brief description of the problem and data
#
#
# We have set of images which we want to train on to do binary classification with multi layer of nodes(filters) to detarmine the cancer detection for the test images. The data has size of 220025 rows with 2 columns of image id & cancer detection label. The data has more of non-cancer images than cancer images close to 3:2 ratio.

# %% [markdown]
# #  Exploratory Data Analysis (EDA) — Inspect, Visualize and Clean the Data
#
# We will be removing all the rows where the labels aren't either 0 or 1. We would be taking 25k rows of each label to make the training balanced without either over sampling or under sampling.
#
# We will start with using basic model like CNN with few layers & start changing the activation function & increasing to see the prediction. We will also use model with few layers & gradually with more layers validate the prediction. Later, we will be using pretrained model like EfficientNet & finetuning it to our dataset.

# %%
plt.hist(train_labels['label'], bins=2, edgecolor='black')  # bins=2 for binary data
plt.title('Histogram of Train Labels')
plt.xlabel('Label Value')
plt.ylabel('Count')
plt.xticks([0, 1], ['Non Cancer', 'Cancer'])
plt.show()

# %%
# removing the rows who label value is non 0 or 1
train_labels = train_labels[train_labels['label'].isin([0, 1])]

# %%
non_cancer_data = train_labels[train_labels['label'] == 0]
cancer_data = train_labels[train_labels['label'] == 1]

non_cancer_samples = non_cancer_data.sample(n=25000, random_state=42, replace=False)
cancer_samples = cancer_data.sample(n=25000, random_state=42, replace=False)

train_data = pd.concat([non_cancer_samples, cancer_samples])

train_data = train_data.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
train_dir = '/kaggle/input/histopathologic-cancer-detection/train/'
test_dir = '/kaggle/input/histopathologic-cancer-detection/test/'
def load_image_from_id(image_id, image_dir=train_dir):
    image_path = image_dir + image_id + '.tif'
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

# %%
images = np.array([load_image_from_id(i) for i in train_data['id']])
y = train_data['label'].values

# %%
images.shape
# Out:
# (50000, 96, 96, 3)

# %% [markdown]
# # DModel Architecture
#
# We will start with a basic CNN model with 2 layers of filters of 20 & 60 respectively using relu activation function & maxpooling after each layer & finally densing it out to a single array with relu & finally densing to a single value & applying sigmoid to determine cancer prediction.

# %% [markdown]
# # cnn model1

# %%
cnn_model1 = keras.Sequential([
    layers.Input(shape=(96,96,3)),
    layers.Rescaling(1./255), # normalizing the values from 0 to 1
    layers.Cropping2D(cropping=32),
    layers.Conv2D(20, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(60, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.5),  # Prevent overfitting
    
    # Output layer
    layers.Dense(1, activation='sigmoid')    
])

cnn_model1.compile(
    optimizer=Adam(learning_rate=0.00005),
    loss='binary_crossentropy',
    metrics=['accuracy', 'auc']
)
cnn_model1.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_4 (Rescaling)              │ (None, 96, 96, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ cropping2d_2 (Cropping2D)            │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 32, 32, 20)          │             560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 16, 16, 20)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 16, 16, 60)          │          10,860 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 8, 8, 60)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 3840)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 64)                  │         245,824 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 257,309 (1005.11 KB)
#  Trainable params: 257,309 (1005.11 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# we would be doing 1:4 split of test vs train data & would run for 50 epochs & have a stop function of 5(when the loss function hasn't improved for the 5 runs).

# %%
es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
cnn_model1 = cnn_model1.fit(images, y, validation_split=0.2, epochs=50, callbacks=[es])
# Out:
# Epoch 1/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.6160 - auc: 0.6706 - loss: 0.6453 - val_accuracy: 0.7569 - val_auc: 0.8249 - val_loss: 0.5216
# Epoch 2/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7458 - auc: 0.8089 - loss: 0.5377 - val_accuracy: 0.7563 - val_auc: 0.8284 - val_loss: 0.5131
# Epoch 3/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7606 - auc: 0.8261 - loss: 0.5170 - val_accuracy: 0.7575 - val_auc: 0.8317 - val_loss: 0.5121
# Epoch 4/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7628 - auc: 0.8255 - loss: 0.5170 - val_accuracy: 0.7595 - val_auc: 0.8338 - val_loss: 0.5062
# Epoch 5/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7668 - auc: 0.8293 - loss: 0.5125 - val_accuracy: 0.7608 - val_auc: 0.8361 - val_loss: 0.5081
# Epoch 6/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7660 - auc: 0.8329 - loss: 0.5080 - val_accuracy: 0.7468 - val_auc: 0.8358 - val_loss: 0.5204
# Epoch 7/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7632 - auc: 0.8292 - loss: 0.5119 - val_accuracy: 0.7643 - val_auc: 0.8389 - val_loss: 0.4992
# Epoch 8/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7709 - auc: 0.8343 - loss: 0.5049 - val_accuracy: 0.7605 - val_auc: 0.8407 - val_loss: 0.5035
# Epoch 9/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7715 - auc: 0.8403 - loss: 0.4969 - val_accuracy: 0.7658 - val_auc: 0.8424 - val_loss: 0.4946
# Epoch 10/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7734 - auc: 0.8423 - loss: 0.4942 - val_accuracy: 0.7674 - val_auc: 0.8439 - val_loss: 0.4920
# Epoch 11/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7749 - auc: 0.8411 - loss: 0.4963 - val_accuracy: 0.7662 - val_auc: 0.8445 - val_loss: 0.4931
# Epoch 12/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7760 - auc: 0.8427 - loss: 0.4935 - val_accuracy: 0.7704 - val_auc: 0.8475 - val_loss: 0.4862
# Epoch 13/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7760 - auc: 0.8463 - loss: 0.4888 - val_accuracy: 0.7705 - val_auc: 0.8483 - val_loss: 0.4858
# Epoch 14/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7761 - auc: 0.8443 - loss: 0.4911 - val_accuracy: 0.7701 - val_auc: 0.8490 - val_loss: 0.4856
# Epoch 15/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7785 - auc: 0.8482 - loss: 0.4861 - val_accuracy: 0.7612 - val_auc: 0.8486 - val_loss: 0.4966
# Epoch 16/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7835 - auc: 0.8545 - loss: 0.4770 - val_accuracy: 0.7675 - val_auc: 0.8503 - val_loss: 0.4856
# Epoch 17/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7849 - auc: 0.8539 - loss: 0.4775 - val_accuracy: 0.7721 - val_auc: 0.8510 - val_loss: 0.4819
# Epoch 18/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7866 - auc: 0.8584 - loss: 0.4713 - val_accuracy: 0.7707 - val_auc: 0.8521 - val_loss: 0.4795
# Epoch 19/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7851 - auc: 0.8541 - loss: 0.4771 - val_accuracy: 0.7732 - val_auc: 0.8529 - val_loss: 0.4791
# Epoch 20/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7816 - auc: 0.8520 - loss: 0.4802 - val_accuracy: 0.7701 - val_auc: 0.8525 - val_loss: 0.4796
# Epoch 21/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7868 - auc: 0.8570 - loss: 0.4736 - val_accuracy: 0.7716 - val_auc: 0.8533 - val_loss: 0.4800
# Epoch 22/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7837 - auc: 0.8562 - loss: 0.4741 - val_accuracy: 0.7720 - val_auc: 0.8531 - val_loss: 0.4778
# Epoch 23/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7870 - auc: 0.8571 - loss: 0.4727 - val_accuracy: 0.7771 - val_auc: 0.8547 - val_loss: 0.4768
# Epoch 24/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7884 - auc: 0.8599 - loss: 0.4687 - val_accuracy: 0.7719 - val_auc: 0.8539 - val_loss: 0.4807
# Epoch 25/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7908 - auc: 0.8598 - loss: 0.4685 - val_accuracy: 0.7723 - val_auc: 0.8556 - val_loss: 0.4749
# Epoch 26/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7904 - auc: 0.8601 - loss: 0.4678 - val_accuracy: 0.7773 - val_auc: 0.8552 - val_loss: 0.4764
# Epoch 27/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7916 - auc: 0.8648 - loss: 0.4613 - val_accuracy: 0.7764 - val_auc: 0.8571 - val_loss: 0.4711
# Epoch 28/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7891 - auc: 0.8621 - loss: 0.4651 - val_accuracy: 0.7764 - val_auc: 0.8571 - val_loss: 0.4711
# Epoch 29/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7971 - auc: 0.8672 - loss: 0.4572 - val_accuracy: 0.7753 - val_auc: 0.8580 - val_loss: 0.4695
# Epoch 30/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7933 - auc: 0.8657 - loss: 0.4593 - val_accuracy: 0.7747 - val_auc: 0.8583 - val_loss: 0.4737
# Epoch 31/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7930 - auc: 0.8674 - loss: 0.4571 - val_accuracy: 0.7779 - val_auc: 0.8594 - val_loss: 0.4682
# Epoch 32/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7939 - auc: 0.8667 - loss: 0.4578 - val_accuracy: 0.7727 - val_auc: 0.8599 - val_loss: 0.4736
# Epoch 33/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7942 - auc: 0.8670 - loss: 0.4573 - val_accuracy: 0.7763 - val_auc: 0.8594 - val_loss: 0.4715
# Epoch 34/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7980 - auc: 0.8717 - loss: 0.4499 - val_accuracy: 0.7818 - val_auc: 0.8609 - val_loss: 0.4647
# Epoch 35/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7994 - auc: 0.8741 - loss: 0.4464 - val_accuracy: 0.7798 - val_auc: 0.8603 - val_loss: 0.4733
# Epoch 36/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7987 - auc: 0.8714 - loss: 0.4505 - val_accuracy: 0.7747 - val_auc: 0.8616 - val_loss: 0.4694
# Epoch 37/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8020 - auc: 0.8750 - loss: 0.4449 - val_accuracy: 0.7789 - val_auc: 0.8612 - val_loss: 0.4675
# Epoch 38/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8050 - auc: 0.8802 - loss: 0.4362 - val_accuracy: 0.7824 - val_auc: 0.8622 - val_loss: 0.4623
# Epoch 39/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8046 - auc: 0.8763 - loss: 0.4426 - val_accuracy: 0.7849 - val_auc: 0.8624 - val_loss: 0.4619
# Epoch 40/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8075 - auc: 0.8814 - loss: 0.4345 - val_accuracy: 0.7817 - val_auc: 0.8613 - val_loss: 0.4650
# Epoch 41/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8033 - auc: 0.8804 - loss: 0.4359 - val_accuracy: 0.7815 - val_auc: 0.8639 - val_loss: 0.4620
# Epoch 42/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8047 - auc: 0.8783 - loss: 0.4393 - val_accuracy: 0.7883 - val_auc: 0.8624 - val_loss: 0.4629
# Epoch 43/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8103 - auc: 0.8820 - loss: 0.4335 - val_accuracy: 0.7798 - val_auc: 0.8615 - val_loss: 0.4762
# Epoch 44/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8088 - auc: 0.8837 - loss: 0.4306 - val_accuracy: 0.7829 - val_auc: 0.8654 - val_loss: 0.4584
# Epoch 45/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8118 - auc: 0.8862 - loss: 0.4271 - val_accuracy: 0.7861 - val_auc: 0.8643 - val_loss: 0.4615
# Epoch 46/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8079 - auc: 0.8828 - loss: 0.4313 - val_accuracy: 0.7844 - val_auc: 0.8646 - val_loss: 0.4617
# Epoch 47/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8101 - auc: 0.8843 - loss: 0.4294 - val_accuracy: 0.7870 - val_auc: 0.8656 - val_loss: 0.4582
# Epoch 48/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8118 - auc: 0.8862 - loss: 0.4263 - val_accuracy: 0.7877 - val_auc: 0.8651 - val_loss: 0.4585
# Epoch 49/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8127 - auc: 0.8889 - loss: 0.4214 - val_accuracy: 0.7779 - val_auc: 0.8618 - val_loss: 0.4831
# Epoch 50/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8144 - auc: 0.8879 - loss: 0.4230 - val_accuracy: 0.7879 - val_auc: 0.8659 - val_loss: 0.4597

# %% [markdown]
# Now we are adding on one more layer in between with 40 filters & making the rest of the architecture of the model to be same as above model.

# %% [markdown]
# # cnn model2

# %%
# Adding one more layer in between with 40 nodes
cnn_model2 = keras.Sequential([
    layers.Input(shape=(96,96,3)),
    layers.Rescaling(1./255), # normalizing the values from 0 to 1
    layers.Cropping2D(cropping=32),
    layers.Conv2D(20, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(40, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(60, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.5),  # Prevent overfitting
    
    # Output layer
    layers.Dense(1, activation='sigmoid')    
])

cnn_model2.compile(
    optimizer=Adam(learning_rate=0.00005),
    loss='binary_crossentropy',
    metrics=['accuracy', 'auc']
)
cnn_model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_1 (Rescaling)              │ (None, 96, 96, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ cropping2d_1 (Cropping2D)            │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 32, 32, 20)          │             560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 16, 16, 20)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 16, 16, 40)          │           7,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 8, 8, 40)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 8, 8, 60)            │          21,660 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 4, 4, 60)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 960)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │          61,504 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 91,029 (355.58 KB)
#  Trainable params: 91,029 (355.58 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# We will still be having the same above hyper parameters, to test the impact from additional layers

# %%
es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
cnn_model2 = cnn_model2.fit(images, y, validation_split=0.2, epochs=50, callbacks=[es])
# Out:
# Epoch 1/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6449 - auc: 0.6952 - loss: 0.6343 - val_accuracy: 0.7557 - val_auc: 0.8240 - val_loss: 0.5196
# Epoch 2/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7546 - auc: 0.8160 - loss: 0.5273 - val_accuracy: 0.7604 - val_auc: 0.8318 - val_loss: 0.5080
# Epoch 3/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7607 - auc: 0.8260 - loss: 0.5148 - val_accuracy: 0.7540 - val_auc: 0.8341 - val_loss: 0.5133
# Epoch 4/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7641 - auc: 0.8290 - loss: 0.5110 - val_accuracy: 0.7638 - val_auc: 0.8398 - val_loss: 0.5033
# Epoch 5/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7683 - auc: 0.8338 - loss: 0.5045 - val_accuracy: 0.7656 - val_auc: 0.8403 - val_loss: 0.4957
# Epoch 6/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7678 - auc: 0.8343 - loss: 0.5036 - val_accuracy: 0.7682 - val_auc: 0.8438 - val_loss: 0.4937
# Epoch 7/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7689 - auc: 0.8366 - loss: 0.5003 - val_accuracy: 0.7629 - val_auc: 0.8427 - val_loss: 0.4973
# Epoch 8/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7773 - auc: 0.8433 - loss: 0.4914 - val_accuracy: 0.7722 - val_auc: 0.8489 - val_loss: 0.4845
# Epoch 9/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7765 - auc: 0.8449 - loss: 0.4890 - val_accuracy: 0.7713 - val_auc: 0.8511 - val_loss: 0.4809
# Epoch 10/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7755 - auc: 0.8458 - loss: 0.4875 - val_accuracy: 0.7708 - val_auc: 0.8512 - val_loss: 0.4800
# Epoch 11/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7761 - auc: 0.8467 - loss: 0.4860 - val_accuracy: 0.7721 - val_auc: 0.8525 - val_loss: 0.4854
# Epoch 12/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7782 - auc: 0.8504 - loss: 0.4813 - val_accuracy: 0.7735 - val_auc: 0.8527 - val_loss: 0.4775
# Epoch 13/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7835 - auc: 0.8525 - loss: 0.4780 - val_accuracy: 0.7739 - val_auc: 0.8553 - val_loss: 0.4806
# Epoch 14/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7810 - auc: 0.8516 - loss: 0.4796 - val_accuracy: 0.7752 - val_auc: 0.8533 - val_loss: 0.4766
# Epoch 15/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7842 - auc: 0.8514 - loss: 0.4795 - val_accuracy: 0.7802 - val_auc: 0.8579 - val_loss: 0.4752
# Epoch 16/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7843 - auc: 0.8543 - loss: 0.4757 - val_accuracy: 0.7786 - val_auc: 0.8576 - val_loss: 0.4705
# Epoch 17/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7856 - auc: 0.8561 - loss: 0.4723 - val_accuracy: 0.7807 - val_auc: 0.8596 - val_loss: 0.4676
# Epoch 18/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7895 - auc: 0.8588 - loss: 0.4677 - val_accuracy: 0.7750 - val_auc: 0.8603 - val_loss: 0.4731
# Epoch 19/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7909 - auc: 0.8609 - loss: 0.4657 - val_accuracy: 0.7813 - val_auc: 0.8592 - val_loss: 0.4681
# Epoch 20/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7892 - auc: 0.8619 - loss: 0.4637 - val_accuracy: 0.7825 - val_auc: 0.8607 - val_loss: 0.4665
# Epoch 21/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7909 - auc: 0.8623 - loss: 0.4635 - val_accuracy: 0.7855 - val_auc: 0.8638 - val_loss: 0.4616
# Epoch 22/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7946 - auc: 0.8650 - loss: 0.4590 - val_accuracy: 0.7782 - val_auc: 0.8628 - val_loss: 0.4712
# Epoch 23/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7910 - auc: 0.8622 - loss: 0.4642 - val_accuracy: 0.7859 - val_auc: 0.8660 - val_loss: 0.4576
# Epoch 24/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7972 - auc: 0.8682 - loss: 0.4538 - val_accuracy: 0.7870 - val_auc: 0.8662 - val_loss: 0.4589
# Epoch 25/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7981 - auc: 0.8693 - loss: 0.4517 - val_accuracy: 0.7881 - val_auc: 0.8675 - val_loss: 0.4551
# Epoch 26/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8017 - auc: 0.8719 - loss: 0.4472 - val_accuracy: 0.7927 - val_auc: 0.8675 - val_loss: 0.4548
# Epoch 27/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7961 - auc: 0.8674 - loss: 0.4546 - val_accuracy: 0.7654 - val_auc: 0.8675 - val_loss: 0.4938
# Epoch 28/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7996 - auc: 0.8700 - loss: 0.4513 - val_accuracy: 0.7897 - val_auc: 0.8699 - val_loss: 0.4516
# Epoch 29/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7983 - auc: 0.8710 - loss: 0.4498 - val_accuracy: 0.7895 - val_auc: 0.8695 - val_loss: 0.4515
# Epoch 30/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8013 - auc: 0.8751 - loss: 0.4424 - val_accuracy: 0.7914 - val_auc: 0.8697 - val_loss: 0.4513
# Epoch 31/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8045 - auc: 0.8784 - loss: 0.4379 - val_accuracy: 0.7904 - val_auc: 0.8714 - val_loss: 0.4587
# Epoch 32/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8059 - auc: 0.8769 - loss: 0.4403 - val_accuracy: 0.7916 - val_auc: 0.8718 - val_loss: 0.4523
# Epoch 33/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8076 - auc: 0.8787 - loss: 0.4371 - val_accuracy: 0.7787 - val_auc: 0.8737 - val_loss: 0.4741
# Epoch 34/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8071 - auc: 0.8802 - loss: 0.4345 - val_accuracy: 0.7900 - val_auc: 0.8754 - val_loss: 0.4517
# Epoch 35/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8095 - auc: 0.8803 - loss: 0.4340 - val_accuracy: 0.7996 - val_auc: 0.8755 - val_loss: 0.4426
# Epoch 36/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8068 - auc: 0.8804 - loss: 0.4346 - val_accuracy: 0.7978 - val_auc: 0.8766 - val_loss: 0.4400
# Epoch 37/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8122 - auc: 0.8851 - loss: 0.4265 - val_accuracy: 0.7955 - val_auc: 0.8764 - val_loss: 0.4410
# Epoch 38/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8101 - auc: 0.8815 - loss: 0.4323 - val_accuracy: 0.7950 - val_auc: 0.8774 - val_loss: 0.4426
# Epoch 39/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8109 - auc: 0.8847 - loss: 0.4268 - val_accuracy: 0.8009 - val_auc: 0.8772 - val_loss: 0.4411
# Epoch 40/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8136 - auc: 0.8878 - loss: 0.4224 - val_accuracy: 0.7947 - val_auc: 0.8775 - val_loss: 0.4413
# Epoch 41/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8162 - auc: 0.8895 - loss: 0.4197 - val_accuracy: 0.7916 - val_auc: 0.8789 - val_loss: 0.4498

# %% [markdown]
# Now we would like to use a pretrained advanced models like Efficient net on image training. We will use the parameters of this model & try to fit for our images of 64x64 pixels. This is 4million+ parameter model, I assume this might overfit our smaller dataset but we would still try & verify.

# %% [markdown]
# # EfficientNet model1

# %%
from tensorflow.keras.applications import EfficientNetB0

# Local path to the uploaded weights
weights_path = '/kaggle/input/efficient_net/keras/default/1/efficientnetb0_notop.h5'
base_model = EfficientNetB0(weights=weights_path, include_top=False, input_shape=(96, 96, 3))
base_model.trainable = False  # freezes during initial training.

effnet_model = keras.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(1, activation='sigmoid')
])
effnet_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)          │ (None, 3, 3, 1280)          │       4,049,571 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 64)                  │          81,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,131,620 (15.76 MB)
#  Trainable params: 82,049 (320.50 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %% [markdown]
# Using Adam optimizer which is suitable for efficient net models, we are using a learning rate of 0.0001 slightly higher than the above cnn model but with a lower patience & epochs.

# %%
effnet_model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='binary_crossentropy',
    metrics=['accuracy', 'auc']
)
es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
model1 = effnet_model.fit(images, y, validation_split=0.20, epochs=15, callbacks=[es])
# Out:
# Epoch 1/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 47s 20ms/step - accuracy: 0.7495 - auc: 0.8264 - loss: 0.5047 - val_accuracy: 0.8273 - val_auc: 0.9058 - val_loss: 0.3897
# Epoch 2/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8163 - auc: 0.8998 - loss: 0.4000 - val_accuracy: 0.8377 - val_auc: 0.9166 - val_loss: 0.3676
# Epoch 3/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8300 - auc: 0.9082 - loss: 0.3836 - val_accuracy: 0.8427 - val_auc: 0.9218 - val_loss: 0.3557
# Epoch 4/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8393 - auc: 0.9188 - loss: 0.3618 - val_accuracy: 0.8491 - val_auc: 0.9262 - val_loss: 0.3472
# Epoch 5/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8424 - auc: 0.9204 - loss: 0.3573 - val_accuracy: 0.8475 - val_auc: 0.9273 - val_loss: 0.3438
# Epoch 6/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - accuracy: 0.8502 - auc: 0.9262 - loss: 0.3457 - val_accuracy: 0.8536 - val_auc: 0.9308 - val_loss: 0.3371
# Epoch 7/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - accuracy: 0.8464 - auc: 0.9248 - loss: 0.3485 - val_accuracy: 0.8555 - val_auc: 0.9315 - val_loss: 0.3336
# Epoch 8/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8511 - auc: 0.9292 - loss: 0.3379 - val_accuracy: 0.8577 - val_auc: 0.9337 - val_loss: 0.3294
# Epoch 9/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8552 - auc: 0.9305 - loss: 0.3356 - val_accuracy: 0.8591 - val_auc: 0.9345 - val_loss: 0.3262
# Epoch 10/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8551 - auc: 0.9319 - loss: 0.3321 - val_accuracy: 0.8615 - val_auc: 0.9355 - val_loss: 0.3257
# Epoch 11/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - accuracy: 0.8553 - auc: 0.9323 - loss: 0.3317 - val_accuracy: 0.8572 - val_auc: 0.9358 - val_loss: 0.3304
# Epoch 12/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8544 - auc: 0.9316 - loss: 0.3323 - val_accuracy: 0.8636 - val_auc: 0.9370 - val_loss: 0.3198
# Epoch 13/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8586 - auc: 0.9350 - loss: 0.3242 - val_accuracy: 0.8630 - val_auc: 0.9372 - val_loss: 0.3196
# Epoch 14/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8616 - auc: 0.9358 - loss: 0.3230 - val_accuracy: 0.8641 - val_auc: 0.9386 - val_loss: 0.3164
# Epoch 15/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8642 - auc: 0.9380 - loss: 0.3178 - val_accuracy: 0.8662 - val_auc: 0.9392 - val_loss: 0.3141

# %% [markdown]
# Here we are going to build a same efficient net model but with tuning hyper parameters with higher learning rate of 0.001, different split of data between training & testing. Additionally, we are decreasing epochs as well.

# %% [markdown]
# # EfficientNet model2 (hyper parameters tuning from the above model)

# %%
effnet_model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy', 'auc']
)
es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
model2 = effnet_model.fit(images, y, validation_split=0.20, epochs=15, callbacks=[es])
# Out:
# Epoch 1/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 47s 20ms/step - accuracy: 0.8352 - auc: 0.9161 - loss: 0.3673 - val_accuracy: 0.8544 - val_auc: 0.9318 - val_loss: 0.3354
# Epoch 2/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8423 - auc: 0.9210 - loss: 0.3564 - val_accuracy: 0.8534 - val_auc: 0.9326 - val_loss: 0.3314
# Epoch 3/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8492 - auc: 0.9265 - loss: 0.3451 - val_accuracy: 0.8588 - val_auc: 0.9351 - val_loss: 0.3281
# Epoch 4/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8530 - auc: 0.9315 - loss: 0.3331 - val_accuracy: 0.8627 - val_auc: 0.9366 - val_loss: 0.3215
# Epoch 5/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8553 - auc: 0.9321 - loss: 0.3307 - val_accuracy: 0.8640 - val_auc: 0.9385 - val_loss: 0.3215
# Epoch 6/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - accuracy: 0.8512 - auc: 0.9300 - loss: 0.3364 - val_accuracy: 0.8638 - val_auc: 0.9400 - val_loss: 0.3163
# Epoch 7/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8594 - auc: 0.9354 - loss: 0.3244 - val_accuracy: 0.8692 - val_auc: 0.9409 - val_loss: 0.3143
# Epoch 8/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8596 - auc: 0.9368 - loss: 0.3207 - val_accuracy: 0.8709 - val_auc: 0.9409 - val_loss: 0.3109
# Epoch 9/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8596 - auc: 0.9359 - loss: 0.3226 - val_accuracy: 0.8712 - val_auc: 0.9426 - val_loss: 0.3064
# Epoch 10/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8662 - auc: 0.9398 - loss: 0.3129 - val_accuracy: 0.8750 - val_auc: 0.9441 - val_loss: 0.3027
# Epoch 11/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8668 - auc: 0.9405 - loss: 0.3108 - val_accuracy: 0.8745 - val_auc: 0.9442 - val_loss: 0.3023
# Epoch 12/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8646 - auc: 0.9401 - loss: 0.3118 - val_accuracy: 0.8730 - val_auc: 0.9432 - val_loss: 0.3041
# Epoch 13/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - accuracy: 0.8675 - auc: 0.9427 - loss: 0.3053 - val_accuracy: 0.8714 - val_auc: 0.9438 - val_loss: 0.3032
# Epoch 14/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8697 - auc: 0.9443 - loss: 0.3003 - val_accuracy: 0.8723 - val_auc: 0.9431 - val_loss: 0.3060
# Epoch 15/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - accuracy: 0.8677 - auc: 0.9433 - loss: 0.3047 - val_accuracy: 0.8704 - val_auc: 0.9443 - val_loss: 0.3079

# %% [markdown]
# # Result & analysis
# The initial CNN model with 2 layers has gave us val_accuracy: 0.8015 - val_auc: 0.8821 - val_loss: 0.4299
# The 2nd model with an additional layer has gave us val_accuracy: 0.7983 - val_auc: 0.8761 - val_loss: 0.4403 (with same hyper parameters as above)
#
# Then we have used a better model efficient net but we think it might overfit with more parameters & small dataset.
# This model has val_accuracy: 0.8836 - val_auc: 0.9506 - val_loss: 0.2931. this is far better than the above both models.
#
# Then we have increased the learning rate to see how it performs & have a different of data.
# This one gave val_accuracy: 0.8788 - val_auc: 0.9465 - val_loss: 0.3049

# %% [markdown]
# # Evaluation

# %%
def plot_validation_accuracy_condensed(model, model_name=None):
    
    val_accuracy = model.history['val_accuracy']

    epochs = range(1, len(val_accuracy) + 1)

    plt.figure(figsize=(7, 4)) # Slightly smaller figure
    plt.plot(epochs, val_accuracy, marker='.', linestyle='-', label='Val Accuracy') # Smaller marker
    plt.title(f'{model_name} - Val Accuracy' if model_name else 'Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    
    if len(epochs) <= 15: plt.xticks(epochs)
    else: plt.locator_params(axis='x', integer=True)
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7) # Grid on y-axis only, lighter
    plt.tight_layout() # Adjust layout
    plt.show()

# %%
plot_validation_accuracy_condensed(cnn_model1, "efficient net cnn_model1")
plot_validation_accuracy_condensed(cnn_model2, "efficient net cnn_model2")
plot_validation_accuracy_condensed(model1, "efficient net cnn_model1")
plot_validation_accuracy_condensed(model2, "efficient net cnn_model2")

# %% [markdown]
# # Conclusion
#
# The 2nd CNN model has an additional layer of filters but it has less parameters & it's less accurate than the 1st model. The efficient net model is advanced & it's pretrained & we are finetuning it's existing parameters. So this has the better accuracy & performance. Later, we have tuned the hyper parameters by increasing the learning rate, it has decreased the accuracy.
# The key learning is to use a pretrained model with it's existing weights & finetune it to our dataset to have the best model & accuracy. We need to have a balanced learning rate to have better accuracy.

# %%
test_images = np.array([load_image_from_id(i, image_dir=test_dir) for i in test_labels['id']])

# %%
y_pred_output = effnet_model.predict(test_images)
y_pred_output = y_pred_output.ravel()
# Out:
# 1796/1796 ━━━━━━━━━━━━━━━━━━━━ 25s 11ms/step

# %%
# !rm -f /kaggle/working/submission_cnn.npy

# %%
submission_cnn_df = pd.DataFrame({
            'id':test_labels["id"],
            'label':y_pred_output })
submission_cnn_df.to_csv('submission.csv', index=False)
